# %% [markdown]
# <a href="https://colab.research.google.com/github/prashant-659/Netflix-Recommendation-System-in-Collab/blob/main/Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import required libraries

# %%
import pandas as pd # library for data analysis
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML documents

# %%
# get the response in the form of html
wikiurl="https://en.wikipedia.org/wiki/Economy_of_India"
table_class="infobox"
response=requests.get(wikiurl)
print(response.status_code)
# Out:
# 200

# %%
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(response.text, 'html.parser')
indiatable=soup.find('table',{'class':"infobox"})

# %%
soup.title.string
# Out:
# 'Economy of India - Wikipedia'

# %%
# use the 'find_all' function to bring back all instances of the 'table'
# tag in the HTML and store in 'all_tables' variable
#'required_ table' is the table containing the required information
all_tables=soup.find_all("table")
required_table=all_tables[4]

# %%
required_table
# Out:
# <table class="wikitable" style="text-align:center;">
# <tbody><tr>
# <th>Year
# </th>
# <th>GDP<br/><small>(in Bil. US$PPP)</small>
# </th>
# <th>GDP per capita<br/><small>(in US$ PPP)</small>
# </th>
# <th>GDP<br/><small>(in Bil. US$nominal)</small>
# </th>
# <th>GDP per capita<br/><small>(in US$ nominal)</small>
# </th>
# <th>GDP growth<br/><small>(real)</small>
# </th>
# <th>Inflation rate<br/><small>(in Percent)</small>
# </th>
# <th>Unemployment<br/><small>(in Percent)</small>
# </th>
# <th>Government debt<br/><small>(in % of GDP)</small>
# </th></tr>
# <tr>
# <td>1980
# </td>
# <td>371.9
# </td>
# <td>532.0
# </td>
# <td>189.4
# </td>
# <td>271.0
# </td>
# ...

# %%
#empty lists to fill the table with required columns
A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
G=[]
H=[]
I=[]


#for loop to append the values of each row in a column of the table
for row in required_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==9:
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))
        D.append(cells[3].find(text=True))
        E.append(cells[4].find(text=True))
        F.append(cells[5].find(text=True))
        G.append(cells[6].find(text=True))
        H.append(cells[7].find(text=True))
        I.append(cells[8].find(text=True))

 #replacing "\n" for each value of every row
A = [item.replace("\n", "") for item in A]
B = [item.replace("\n", "") for item in B]
C = [item.replace("\n", "") for item in C]
D = [item.replace("\n", "") for item in C]
E = [item.replace("\n", "") for item in E]
F = [item.replace("\n", "") for item in F]
G = [item.replace("\n", "") for item in G]
H = [item.replace("\n", "") for item in H]
I = [item.replace("\n", "") for item in I]

B=[item.replace(",", "") for item in B]
C=[item.replace(",", "") for item in C]
D=[item.replace(",", "") for item in D]
E=[item.replace(",", "") for item in E]
F = [item.replace("%", "") for item in F]
G = [item.replace("%", "") for item in G]
H = [item.replace("%", "") for item in H]
I = [item.replace("%", "") for item in I]
H = [item.replace("n/a", "0") for item in H]
I = [item.replace("n/a", "0") for item in I]
# Out:
# <ipython-input-7-a1701984232f>:17: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   A.append(cells[0].find(text=True))
# <ipython-input-7-a1701984232f>:18: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   B.append(cells[1].find(text=True))
# <ipython-input-7-a1701984232f>:19: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   C.append(cells[2].find(text=True))
# <ipython-input-7-a1701984232f>:20: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   D.append(cells[3].find(text=True))
# <ipython-input-7-a1701984232f>:21: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   E.append(cells[4].find(text=True))
# ...

# %% [markdown]
# Summarizing the data into a dataframe

# %%
Eco_Ind=pd.DataFrame(A, columns=['Year'])
Eco_Ind['GDP (in Bil. US $ PPP)']=B
Eco_Ind['GDP Per Capita (in US $ PPP)']=C
Eco_Ind['GDP (in US $ nominal)']=D
Eco_Ind['GDP Per Capita(in US $ nominal)']=E
Eco_Ind['GDP Growth (real %)']=F
Eco_Ind['Inflation Rate (%)']=G
Eco_Ind['Unemployment (%)']=H
Eco_Ind['Government Debt (%)']=I

# %%
Eco_Ind
# Out:
#     Year GDP (in Bil. US $ PPP) GDP Per Capita (in US $ PPP)  \
# 0   1980                  371.9                        532.0
# 1   1981                  431.5                        603.2
# 2   1982                  474.1                        647.5
# 3   1983                  528.6                        705.3
# 4   1984                  568.6                        741.4
# 5   1985                  617.4                        787.1
# 6   1986                  659.9                        822.8
# 7   1987                  703.0                        857.7
# 8   1988                  797.9                        952.7
# 9   1989                  878.5                       1027.0
# 10  1990                  961.8                       1101.3
# 11  1991                 1004.8                       1127.4
# 12  1992                 1084.1                       1192.2
# 13  1993                 1162.5                       1253.5
# ...

# %%
Eco_Ind.head()
for i in Eco_Ind['GDP (in Bil. US $ PPP)']:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
print(type(Eco_Ind['GDP (in Bil. US $ PPP)']))
Eco_Ind.columns
# Out:
# <class 'pandas.core.series.Series'>
# Index(['Year', 'GDP (in Bil. US $ PPP)', 'GDP Per Capita (in US $ PPP)',
#        'GDP (in US $ nominal)', 'GDP Per Capita(in US $ nominal)',
#        'GDP Growth (real %)', 'Inflation Rate (%)', 'Unemployment (%)',
#        'Government Debt (%)'],
#       dtype='object')

# %%
Eco_Ind=Eco_Ind.astype({"Year": "int","GDP (in Bil. US $ PPP)": "float","GDP Per Capita (in US $ PPP)": "float","GDP (in US $ nominal)": "float","GDP Growth (real %)": "float","Inflation Rate (%)": "float"})
type(Eco_Ind['Year'])
# Out:
# pandas.core.series.Series

# %%
Eco_Ind['Unemployment (%)'] = Eco_Ind['Unemployment (%)'].fillna(0).astype(float)
Eco_Ind['Inflation Rate (%)'] = Eco_Ind['Inflation Rate (%)'].fillna(0).astype(float)
Eco_Ind['Inflation Rate (%)'] = Eco_Ind['Inflation Rate (%)'].fillna(0).astype(float)

# %%
Eco_Ind.head()
for i in Eco_Ind['GDP (in Bil. US $ PPP)']:
    print(type(i))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
#Converting to CSV
Eco_Ind.to_csv("Economy_of_India_Wiki_1.csv")
